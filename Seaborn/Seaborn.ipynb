# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# loading dataset 
data = sns.load_dataset("iris") 
  
# draw lineplot 
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
plt.title('Title using Matplotlib Function')
  
plt.show()

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
plt.xlim(5)
  
plt.show()

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
# changing the theme to dark
sns.set_style("dark")
plt.show()

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
# Removing the spines
sns.despine()
plt.show()

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
# Setting the scale of the plot
sns.set_context("paper")
  
plt.show()

# %%
def plot():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
with sns.axes_style('darkgrid'):
      
    # Adding the subplot
    plt.subplot(211)
    plot()
      
plt.subplot(212)
plot()

# %%
palette = sns.color_palette()
  

sns.palplot(palette)
  
plt.show()

# %%
palette = sns.color_palette('PiYG', 11)
  

sns.palplot(palette)
  
plt.show()

# %%
def plot():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)
  
sns.set_palette('vlag')
plt.subplot(211)
  

plot()
  

sns.set_palette('Accent')
plt.subplot(212)
plot()
  
plt.show()

# %%
def graph():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)
  

fig = plt.figure(figsize =(5, 4)) 
  
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
  
graph()
  
ax2 = fig.add_axes([0.5, 0.5, 0.3, 0.3])
  
graph()
  
plt.show()

# %%
def graph():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)
  

plt.subplot(121)
graph()
  

plt.subplot(122)
graph()
  
plt.show()

# %%
def graph():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)
  
axes1 = plt.subplot2grid ( (7, 1), (0, 0), rowspan = 2,  colspan = 1) 
graph()
  
axes2 = plt.subplot2grid ( (7, 1), (2, 0), rowspan = 2, colspan = 1) 
graph()
    
axes3 = plt.subplot2grid (
  (7, 1), (4, 0), rowspan = 2, colspan = 1)
graph()

# %%
plot = sns.FacetGrid(data, col="species")
plot.map(plt.plot, "sepal_width")
  
plt.show()
# Out:
# c:\Users\Youssif Allam\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data = sns.load_dataset("flights")
  
plot = sns.PairGrid(data)
plot.map(plt.plot)
  
plt.show()

# %%
data = sns.load_dataset("iris")
  
# creating the relplot
sns.relplot(x='sepal_width', y='species', data=data)
  
plt.show()
# Out:
# c:\Users\Youssif Allam\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=data)
plt.show()

# %%
sns.lineplot(x='sepal_length', y='species', data=data)
plt.show()

# %%
sns.barplot(x='species', y='sepal_length', data=data)
plt.show()

# %%
sns.countplot(x='species', data=data)
plt.show()

# %%
sns.boxplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
sns.violinplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
sns.stripplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
sns.histplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
sns.distplot(data['sepal_width'])
plt.show()
# Out:
# C:\Users\Youssif Allam\AppData\Local\Temp\ipykernel_3336\2803126276.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['sepal_width'])

# %%
sns.jointplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
sns.pairplot(data=data, hue='species')
plt.show()
# Out:
# c:\Users\Youssif Allam\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.rugplot(data=data)
plt.show()

# %%
sns.kdeplot(x='sepal_length', y='sepal_width', data=data)
plt.show()

# %%
data = sns.load_dataset("tips")
  
sns.lmplot(x='total_bill', y='tip', data=data)
plt.show()
# Out:
# c:\Users\Youssif Allam\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
