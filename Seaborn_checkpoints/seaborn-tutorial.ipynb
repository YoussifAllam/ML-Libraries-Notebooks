# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1382, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1381     body = _encode(body, 'body')
# ...

# %%
['anagrams',
 'anscombe',
 'attention',
 'brain_networks',
 'car_crashes',
 'diamonds',
 'dots',
 'dowjones',
 'exercise',
 'flights',
 'fmri',
 'geyser',
 'glue',
 'healthexp',
 'iris',
 'mpg',
 'penguins',
 'planets',
 'seaice',
 'taxis',
 'tips',
 'titanic']

# %%
iris = sns.load_dataset("iris")
tips = sns.load_dataset("tips")
titanic = sns.load_dataset("titanic")

# %%
tips

# %%
'''tips["day"].value_counts().plot(kind="barh")
tips["day"].value_counts().plot(kind="pie", autopct="%1.1f%%")'''
# Out:
# 'tips["day"].value_counts().plot(kind="barh")\ntips["day"].value_counts().plot(kind="pie", autopct="%1.1f%%")'

# %%
#scatterplot 
sns.scatterplot(x="total_bill", y="tip" , data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#add an extra column (day)
sns.scatterplot(x="total_bill", y="tip" , data=tips , hue = "day")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#you can mange the size of it 
#plt.scatter(tips["total_bill"], tips["tip"])
sns.scatterplot(x="total_bill", y="tip" , data=tips , hue = "day", size ="size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#you can manage the color by mention two letters of any color in (palette = "")
sns.scatterplot(x="total_bill", y="tip" , data=tips , hue = "day", size ="size", palette = "YlGnBu")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#histographs (kde is the line if you want to put it or no)(bins = number of bins you want )
sns.histplot(tips["tip"], bins=20, kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#distripution plot
sns.displot(tips["tip"], kde = True , bins = 15, color ="red")

# %%
x = tips[tips["sex"] == "Male"]
x["total_bill"].sum()
# Out:
# 3256.8199999999997

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#bar plot 
sns.barplot(x="sex", y="total_bill" , data=tips, hue="day", estimator=sum)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x="day", y="total_bill", data=tips, estimator=sum, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#bar plot 
sns.barplot(x="total_bill", y="sex" , data=tips, palette = "YlGnBu", estimator=sum)
# Out:
# C:\Users\20115\AppData\Local\Temp\ipykernel_7272\736261187.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="total_bill", y="sex" , data=tips, palette = "YlGnBu", estimator=sum)
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.histplot(data=tips, x="tip", bins=15, kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.boxplot(data=tips, x="tip")
# Out:
# <Axes: xlabel='tip'>

# %%
sns.boxplot(data=tips, x="sex", y="tip")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(data=tips, x="day", y="tip", hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # **Box plots**

# %%
sns.histplot(tips["tip"], kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#box plot 
sns.boxplot(x="tip", data=tips,  palette="YlGnBu")
# Out:
# C:\Users\20115\AppData\Local\Temp\ipykernel_7272\1086916862.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="tip", data=tips,  palette="YlGnBu")
# <Axes: xlabel='tip'>

# %%
sns.boxplot(x="sex",y="tip" , data=tips,  palette="YlGnBu")
# Out:
# C:\Users\20115\AppData\Local\Temp\ipykernel_7272\2333549071.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="sex",y="tip" , data=tips,  palette="YlGnBu")
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x="day", y="tip", data=tips, hue="sex", palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # **strip plots**

# %%
#strip plot 
sns.stripplot(x="day", y="tip", data=tips  )
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x="day", y="tip", data=tips, hue="sex" , palette = "YlGnBu" )
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
# you use dodge to separate the colors 
sns.stripplot(x="day", y="tip", data=tips, hue="sex" , palette = "YlGnBu", dodge = True )
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(x="day", y="tip", data=tips, hue="sex" , palette = "YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x="day", y="tip", data=tips, hue="sex" , palette = "YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # Regression Plot

# %%
sns.lmplot(x ='total_bill', y ='tip', data = tips)

# %%
sns.lmplot(x ='total_bill', y ='tip', data = tips,
           hue ='sex', scatter_kws={"s" : 60}, palette="viridis", markers=["o", "v"])

# %% [markdown]
# # **Joint plots**

# %%
#joint plot 
# it make a scatter plot for 2 columns and show you the distripution of each one 
sns.jointplot(x="total_bill", y="tip", data=tips )

# %%
#reg prefer for a regretion line 
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg")

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde", fill = True)

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde",fill =True, cmap="YlGnBu")

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="resid")

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex", cmap="YlGnBu")

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hist")

# %% [markdown]
# # **Pair plots**

# %% [markdown]
# # Pair plots will plot scatterplots for numerical columns and histograms for the diagonal where a variable is plotted against itself. It's a quick way to visualize relationships between multiple variables in your dataset.

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='sex', kind='scatter', diag_kind='kde')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
numeric = titanic.select_dtypes(["number"])
numeric["sex"] = titanic["sex"]
numeric
# Out:
#      survived  pclass   age  sibsp  parch     fare     sex
# 0           0       3  22.0      1      0   7.2500    male
# 1           1       1  38.0      1      0  71.2833  female
# 2           1       3  26.0      0      0   7.9250  female
# 3           1       1  35.0      1      0  53.1000  female
# 4           0       3  35.0      0      0   8.0500    male
# ..        ...     ...   ...    ...    ...      ...     ...
# 886         0       2  27.0      0      0  13.0000    male
# 887         1       1  19.0      0      0  30.0000  female
# 888         0       3   NaN      1      2  23.4500  female
# 889         1       1  26.0      0      0  30.0000    male
# 890         0       3  32.0      0      0   7.7500    male
#
# [891 rows x 7 columns]

# %%
sns.pairplot(numeric, hue="sex" )

# %% [markdown]
# # **Heat map plot**

# %%
matrix = titanic.corr(numeric_only=True)
#sns.heatmap(titanic.corr(), annot=True, cmap="YlGnBu") #icefire, coolwarm
#sns.heatmap(titanic.corr(), annot=True, cmap="icefire")
sns.heatmap(matrix, annot=True, cmap="coolwarm") #icefire, coolwarm, viridis
# Out:
# <Axes: >

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # set style

# %%
#('darkgrid', 'whitegrid', 'dark', 'white', 'ticks')

# %%
sns.set_style('whitegrid')
sns.lmplot(x ='total_bill', y ='tip', data = tips)

# %%
sns.set_style('darkgrid')
sns.lmplot(x ='total_bill', y ='tip', data = tips)

# %%
sns.set_style('dark')
sns.lmplot(x ='total_bill', y ='tip', data = tips)

# %%
sns.set_style('white')
sns.lmplot(x ='total_bill', y ='tip', data = tips)

# %%
sns.set_style('ticks')
sns.lmplot(x ='total_bill', y ='tip', data = tips)
