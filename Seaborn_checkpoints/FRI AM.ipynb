# %%
pip install seaborn

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
tips.to_csv("tips.csv")

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", size="size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day", size="size", palette="YlGnBu")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=tips, x="tip", kde=True, bins=15, color="red")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.boxplot(data=tips, x="tip", palette="YlGnBu")
# Out:
# C:\Users\20115\AppData\Local\Temp\ipykernel_7328\1164180391.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tips, x="tip", palette="YlGnBu")
# <Axes: xlabel='tip'>

# %%
sns.boxplot(data=tips, x="day", y="tip", hue="day", palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(data=tips, x="day", y="tip", hue="sex", palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.countplot(data=tips, y="sex", hue="sex")
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.countplot(data=tips, x="sex", hue="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(data=tips, x="sex", y="total_bill", hue="sex")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x="sex", y="total_bill", hue="sex", estimator=sum)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
tips["total_bill"].sum()
# Out:
# 4827.77

# %%
tips["total_bill"][tips["sex"] == "Male"].sum()
# Out:
# 3256.8199999999997

# %%
sns.barplot(data=tips, x="sex", y="total_bill", estimator=sum, hue="day" , palette="YlGnBu")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x="day", y="total_bill", estimator=sum, hue="sex" , palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips, x="day", y="tip", palette="YlGnBu")
# Out:
# C:\Users\20115\AppData\Local\Temp\ipykernel_7328\760299188.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tips, x="day", y="tip", palette="YlGnBu")
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data=tips, x="day", y="tip", palette="YlGnBu")
# Out:
# C:\Users\20115\AppData\Local\Temp\ipykernel_7328\3896776153.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=tips, x="day", y="tip", palette="YlGnBu")
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(data=tips, x="day", y="tip", palette="YlGnBu")
# Out:
# C:\Users\20115\AppData\Local\Temp\ipykernel_7328\717455214.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=tips, x="day", y="tip", palette="YlGnBu")
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(data=tips, x="day", y="tip", palette="YlGnBu")
# Out:
# C:\Users\20115\AppData\Local\Temp\ipykernel_7328\2414860166.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=tips, x="day", y="tip", palette="YlGnBu")
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data=tips, x="day", y="tip", palette="YlGnBu", hue="sex", dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lmplot(data=tips, x="total_bill", y="tip")

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex")

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex", palette="viridis", markers=["o", "v"])

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
x1 = tips.corr(numeric_only=True)
x1
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
titanic = sns.load_dataset("titanic")
x2 = titanic.corr(numeric_only=True)
x2
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(x1, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.heatmap(x2, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.set_style("dark")
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex", palette="viridis", markers=["o", "v"])

# %%
sns.set_style("white")
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex", palette="viridis", markers=["o", "v"])

# %%
sns.set_style("whitegrid")
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex", palette="viridis", markers=["o", "v"])

# %%
sns.set_style("darkgrid")
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex", palette="viridis", markers=["o", "v"])

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex")
titanic = sns.load_dataset("titanic")
x2 = titanic.corr(numeric_only=True)
sns.heatmap(x2, annot=True, cmap="coolwarm")
sns.set_style("darkgrid")
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex", palette="viridis", markers=["o", "v"])

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex")
titanic = sns.load_dataset("titanic")
x2 = titanic.corr(numeric_only=True)
sns.heatmap(x2, annot=True, cmap="coolwarm")
sns.set_style("darkgrid")
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex", palette="viridis", markers=["o", "v"])
