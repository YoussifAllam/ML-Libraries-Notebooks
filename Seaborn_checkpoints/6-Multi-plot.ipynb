# %%
  '''
It is a useful approach to draw multiple instances of the same plot on different subsets of your dataset.
It allows a viewer to quickly extract a large amount of information about a complex dataset.
In Seaborn, we will plot multiple graphs in a single window in two ways.
First with the help of Facetgrid() function and other by implicit with the help of matplotlib.
'''
# Out:
# '\nIt is a useful approach to draw multiple instances of the same plot on different subsets of your dataset.\nIt allows a viewer to quickly extract a large amount of information about a complex dataset.\nIn Seaborn, we will plot multiple graphs in a single window in two ways.\nFirst with the help of Facetgrid() function and other by implicit with the help of matplotlib.\n'

# %%
'''
FacetGrid: FacetGrid is a general way of ploting grids based on a function.
It helps in visualizing distribution of one variable as well as the relationship
between multiple variables. Its object uses the dataframe as Input and the names
of the variables that shape the column, row, or color dimensions of the grid
'''
# Out:
# '\nFacetGrid: FacetGrid is a general way of ploting grids based on a function.\nIt helps in visualizing distribution of one variable as well as the relationship\nbetween multiple variables. Its object uses the dataframe as Input and the names\nof the variables that shape the column, row, or color dimensions of the grid\n'

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# loading of a dataframe from seaborn
exercise = sns.load_dataset("exercise")
exercise.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
print(exercise['time'].unique())
print(exercise['kind'].unique())
# Out:
# ['1 min', '15 min', '30 min']
# Categories (3, object): ['1 min', '15 min', '30 min']
# ['rest', 'walking', 'running']
# Categories (3, object): ['rest', 'walking', 'running']

# %%
# Form a facetgrid using columns
sea = sns.FacetGrid(exercise, col = "time")
#sea = sns.FacetGrid(exercise, col = "time", row="kind")

# %%
# Form a facetgrid using columns with a hue
sea = sns.FacetGrid(exercise, col = "time", hue = "kind")



# map the above form facetgrid with some attributes
sea.map(sns.scatterplot, "time", "pulse", alpha = .8)

# adding legend
sea.add_legend()

# %%
#several options for controlling the look of the grid that can be passed to the class constructor.

# %%
exercise["diet"].unique()
# Out:
# ['low fat', 'no fat']
# Categories (2, object): ['no fat', 'low fat']

# %%
sea = sns.FacetGrid(exercise, row = "diet",col = "time",
                    row_order = ["no fat", "low fat"],
                    hue="kind", margin_titles = True)



sea.map(sns.regplot, "id", "pulse",
        fit_reg = False)
sea.add_legend()

# %%
#size of the figure is set by providing the height of each facet, along with the aspect ratio:

# %%
# height = 4: This specifies the height (in inches) of each facet (plot) in the grid.

# aspect = 0.5: This controls the width of the plot relative to its height. By setting the aspect ratio to 0.5, the width of each plot will be half the height.

sea = sns.FacetGrid(exercise, col = "time",
                    height = 4, aspect  =.5)

sea.map(sns.barplot, "diet", "pulse",
        order = ["no fat", "low fat"])

# %%
#the facets will be in the order of appearance of the category levels
exercise.kind.value_counts()
# Out:
# kind
# rest       30
# walking    30
# running    30
# Name: count, dtype: int64

# %%
exercise_kind = exercise.kind.value_counts().index


sea = sns.FacetGrid(exercise, row = "kind",
                    row_order = exercise_kind,
                    height = 1.7, aspect = 4)

sea.map(sns.kdeplot, "id")

# %%
#you can plot it along the columns but “wrap” them so that they span multiple rows

# %%
#plot multiplot grid with the help of pairplot() function

# %%
# importing packages
import seaborn
import matplotlib.pyplot as plt

# loading dataset using seaborn
df = seaborn.load_dataset('tips')

# pairplot with hue sex
seaborn.pairplot(df, hue ='size')
plt.show()

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


fig, axes = plt.subplots(2, 3, figsize=(18, 10))

fig.suptitle('Geeksforgeeks - 2 x 3 axes Box plot with data')

iris = sns.load_dataset("iris")

sns.boxplot(ax=axes[0, 0], data=iris, x='species', y='petal_width')
sns.barplot(ax=axes[0, 1], data=iris, x='species', y='petal_length')
sns.boxplot(ax=axes[0, 2], data=iris, x='species', y='sepal_width')
sns.stripplot(ax=axes[1, 0], data=iris, x='species', y='sepal_length')
sns.swarmplot(ax=axes[1, 1], data=iris, x='species', y='petal_length')
sns.violinplot(ax=axes[1, 2], data=iris, x='species', y='petal_width')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='species', ylabel='petal_width'>
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 18.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
